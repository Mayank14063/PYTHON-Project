# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# Loading the raw data

# %%
df = pd.read_csv(r'C:\Users\himan\OneDrive\Desktop\movies.csv')

# %% [markdown]
# Info about data

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# Checking the null values

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df=df.dropna()

# %% [markdown]
# Cleaning null values

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
df.tail(10)
# Out:
#                       name     rating      genre  year  \
# 7604                Mine 9  Not Rated      Drama  2019
# 7616       High on the Hog          R     Action  2019
# 7643                 Tenet      PG-13     Action  2020
# 7645         Birds of Prey          R     Action  2020
# 7646     The Invisible Man          R      Drama  2020
# 7648     Bad Boys for Life          R     Action  2020
# 7649    Sonic the Hedgehog         PG     Action  2020
# 7650              Dolittle         PG  Adventure  2020
# 7651  The Call of the Wild         PG  Adventure  2020
# 7652     The Eight Hundred  Not Rated     Action  2020
#
#                                released  score     votes           director  \
# 7604              May 19, 2020 (Poland)    6.4    4400.0      Eddie Mensore
# 7616     April 16, 2019 (United States)    3.5     195.0          Tony Wash
# 7643  September 3, 2020 (United States)    7.4  387000.0  Christopher Nolan
# ...

# %% [markdown]
# Checking the data type

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# Changing the data type

# %%
df['votes'] = df['votes'].astype(int)
df['budget'] = df['budget'].astype(int)
df['gross'] = df['gross'].astype(int)
df['runtime'] = df['runtime'].astype(int)

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score    votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000     Stanley Kubrick
# ...

# %%
df.sort_values(by=["gross"], ascending=True).head(10)
# Out:
#                             name     rating   genre  year  \
# 7445           Avengers: Endgame      PG-13  Action  2019
# 5445                      Avatar      PG-13  Action  2009
# 3045                     Titanic      PG-13   Drama  1997
# 3203                  Trojan War      PG-13  Comedy  1997
# 272                     Parasite          R  Horror  1982
# 3681                Ginger Snaps  Not Rated   Drama  2000
# 2434  Philadelphia Experiment II      PG-13  Action  1993
# 5640                 Tanner Hall          R   Drama  2009
# 760                    Crimewave      PG-13  Comedy  1985
# 6147                About Cherry          R   Drama  2012
#
#                                released  score    votes             director  \
# 7445     April 26, 2019 (United States)    8.4   903000        Anthony Russo
# 5445  December 18, 2009 (United States)    7.8  1100000        James Cameron
# 3045  December 19, 1997 (United States)    7.8  1100000        James Cameron
# ...

# %%
df.sort_values(by=["score"], ascending=False).head()
# Out:
#                                                name rating      genre  year  \
# 2443                       The Shawshank Redemption      R      Drama  1994
# 5243                                The Dark Knight  PG-13     Action  2008
# 2247                               Schindler's List      R  Biography  1993
# 2444                                   Pulp Fiction      R      Crime  1994
# 4245  The Lord of the Rings: The Return of the King  PG-13     Action  2003
#
#                                released  score    votes           director  \
# 2443   October 14, 1994 (United States)    9.3  2400000     Frank Darabont
# 5243      July 18, 2008 (United States)    9.0  2400000  Christopher Nolan
# 2247   February 4, 1994 (United States)    8.9  1200000   Steven Spielberg
# 2444   October 14, 1994 (United States)    8.9  1900000  Quentin Tarantino
# 4245  December 17, 2003 (United States)    8.9  1700000      Peter Jackson
#
# ...

# %%
pd.set_option('display.max_rows', None)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# Budget vs gross scatter chart

# %%
 
plt.scatter(x=df["budget"],y=df["gross"])
plt.title("budget vs gross")
plt.xlabel('budget')
plt.ylabel('gross')
plt.show()

# %% [markdown]
# Budget vs gross scatter chart with trend line

# %%
sns.regplot(x=df["budget"],y=df["gross"], ci=50, scatter_kws={'color':"black","alpha":0.5})
plt.show()

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.267631  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.201086  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.550649  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.669203  0.318695
# gross    0.267631  0.201086  0.550649  0.669203  1.000000  0.223667
# runtime  0.075077  0.414068  0.352303  0.318695  0.223667  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.238737  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.122862  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.551440  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.509844  0.231278
# gross    0.238737  0.122862  0.551440  0.509844  1.000000  0.174775
# runtime  0.064824  0.292254  0.205344  0.231278  0.174775  1.000000

# %%
corelation = df.corr(method='pearson')

# %% [markdown]
# Different types of correalation on heatmap

# %%
sns.heatmap(data=corelation, annot=True)
plt.show()

# %%
# let's plot lowest corelation that is year and score

sns.regplot(x=df["year"],y=df["score"], ci=50, scatter_kws={'color':"black","alpha":0.5})
plt.show()

# %%
sns.regplot(x=df["year"],y=df["year"], ci=50, scatter_kws={'color':"black","alpha":0.5})
plt.show()

# %%
# find corelation, initially it was in all int datas but now convert all objcet data as well to int and plot heatchart

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head(10)
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000       757    1818
# 3   204       4      4  1980      1127    7.7   221000       889    1413
# 4   732       6      4  1980      1170    7.3   108000       719     351
# 5  1509       6      9  1980      1922    6.4   123000      1758    3081
# 6  3930       6      0  1980      1359    7.9   188000       974     576
# 7  3122       6      3  1980       530    8.2   330000      1269    1257
# 8  3732       4      0  1980      1346    6.8   101000      1606    1402
# 9  4401       6      3  1980      1755    7.0    10000      2011     280
#
#    star  country    budget      gross  company  runtime
# 0   699       46  19000000   46998772     1426      146
# ...

# %%
df_numerized_heat_data = df_numerized.corr()
sns.heatmap(data=df_numerized_heat_data, annot=True)
plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.014073 -0.180805 -0.238629  0.267631  0.025636  0.201086
# ...

# %%
df_numerized.corr().unstack()
# Out:
# name      name        1.000000
#           rating     -0.029234
#           genre       0.010996
#           year        0.025542
#           released   -0.006152
#           score       0.014450
#           votes       0.012615
#           director    0.015246
#           writer      0.012880
#           star       -0.006882
#           country    -0.025490
#           budget      0.023392
#           gross       0.014073
#           company     0.021697
#           runtime     0.010850
# rating    name       -0.029234
#           rating      1.000000
#           genre       0.147796
#           year        0.019499
#           released    0.018083
#           score       0.065983
#           votes       0.006031
#           director    0.014656
#           writer     -0.003149
#           star        0.009196
#           country     0.008230
#           budget     -0.203946
#           gross      -0.180805
#           company    -0.092357
#           runtime     0.140792
# ...

# %%
unstack = df_numerized.corr().unstack()
unstack_new = unstack[(unstack)>0.5]
unstack_new
# Out:
# name      name        1.000000
# rating    rating      1.000000
# genre     genre       1.000000
# year      year        1.000000
# released  released    1.000000
# score     score       1.000000
# votes     votes       1.000000
#           gross       0.550649
# director  director    1.000000
# writer    writer      1.000000
# star      star        1.000000
# country   country     1.000000
# budget    budget      1.000000
#           gross       0.669203
# gross     votes       0.550649
#           budget      0.669203
#           gross       1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
